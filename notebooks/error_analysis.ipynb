# %% [markdown]
# # Error Analysis
#
# Ce notebook sera complete quand les sorties detaillees du modele final seront disponibles.

# %% [markdown]
# ## Objectif
#
# L'objectif est d'analyser de vraies erreurs du modele sur des images du jeu de test :
# - faux positifs ;
# - faux negatifs ;
# - confusions de classes ;
# - boites mal localisees.

# %% [markdown]
# ## Donnees necessaires
#
# Pour completer ce notebook, il faudra disposer pour plusieurs images du split test :
# - de l'image ;
# - des annotations reelles ;
# - des predictions du modele final ;
# - idealement d'une visualisation avec bounding boxes.

# %% [markdown]
# ## Statut actuel
#
# Les metriques globales du modele sont connues, mais les exemples detailles d'erreurs ne sont pas encore integres ici.
#
# Ce notebook restera donc volontairement minimal jusqu'a reception de sorties concretes du modele final.
